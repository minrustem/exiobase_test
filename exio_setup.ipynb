# %%
import pymrio

DB_PATH = 'D:/Programming/databases/IOT_2022_ixi'
CALC_PATH = 'D:/Programming/databases/IOT_2022_ixi_calc'

exio = pymrio.parse_exiobase3(path=DB_PATH)
exio.calc_all()
exio.save_all(CALC_PATH)
print('Saved to', CALC_PATH)
# Out:
# Saved to D:/Programming/databases/IOT_2022_ixi_calc
